# %%
import csv, sys
import os, glob
import string
from string import ascii_lowercase
import numpy as np
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer
from nltk.tokenize import RegexpTokenizer, word_tokenize
import nltk
import pandas as pd
from nltk.collocations import *
from nltk.probability import FreqDist


output_path = '/home/romina/Documents/work/Speeches_mining/outputs'
input_path = '/home/romina/Documents/work/speeches-segmented/greg-tables'

# %%
os.chdir(output_path)
output = open('output.csv', 'r')
data = pd.read_csv(output, encoding='utf-8')
text = pd.DataFrame(data[['text']])
data = list()
for index, content in text.iterrows():
    data.append(content['text'])

# %%
print(len(data))
text=list()
text.append(data[0])
text.append(data[1])
# Out:
# 272217

# %%
stemmer = SnowballStemmer("english", ignore_stopwords=True)
    ##setting up and extending stopwords
stop = stopwords.words('english')
stop.extend(
    ['nevertheless', 'would', 'nether''the', 'in', 'may', 'also', 'zero', 'one', 'two', 'three', 'four', 'five',
     'six', 'seven', 'eight', 'nine', 'ten', 'quot', 'across', 'among', 'beside', 'however', 'yet',
     'within', '1', '2', '3', '4', '5', '6', '7', '8', '9'] + list(ascii_lowercase))

tokens = []
for statement in text:
    # words = tokenizer.tokenize(statement.lower())
    words = word_tokenize(statement.lower())
    words_clean = []
    for word in words:
        if word not in stop:
            words_clean.append(stemmer.stem(word))
    tokens.append(words_clean)

# %%
n=3
all_trigrams=list()
text_trigram=list()
for token_group in tokens:
    trigram_group = list(nltk.ngrams(token_group, n))
    text_trigram.append(trigram_group)
    for trigram in trigram_group:
        all_trigrams.append(trigram)

# %%
total=len(all_trigrams)
cutoff = 0.00001 * total
fdist = FreqDist(all_trigrams)
# for k,v in fdist.items():
#     print(k,v)
print(cutoff)
selected_trigrmas={k: v for k, v in fdist.items() if v > cutoff}
print(selected_trigrmas)
# Out:
# 0.011170000000000001
# {('speaker', 'move', 'suspend'): 1, ('move', 'suspend', 'rule'): 1, ('suspend', 'rule', 'pass'): 1, ('rule', 'pass', 'bill'): 1, ('pass', 'bill', 'hr'): 1, ('bill', 'hr', '3980'): 1, ('hr', '3980', 'provid'): 1, ('3980', 'provid', 'identifi'): 1, ('provid', 'identifi', 'elimin'): 1, ('identifi', 'elimin', 'redund'): 1, ('elimin', 'redund', 'report'): 2, ('redund', 'report', 'requir'): 1, ('report', 'requir', 'develop'): 1, ('requir', 'develop', 'meaning'): 1, ('develop', 'meaning', 'perform'): 1, ('meaning', 'perform', 'metric'): 1, ('perform', 'metric', 'homeland'): 3, ('metric', 'homeland', 'secur'): 3, ('homeland', 'secur', 'prepared'): 2, ('secur', 'prepared', 'grant'): 2, ('prepared', 'grant', 'purpos'): 1, ('grant', 'purpos', 'amend'): 1, ('purpos', 'amend', 'clerk'): 1, ('amend', 'clerk', 'read'): 1, ('clerk', 'read', 'titl'): 1, ('read', 'titl', 'bill'): 1, ('titl', 'bill', 'text'): 1, ('bill', 'text', 'bill'): 1, ('text', 'bill', 'follow'): 1, ('bill', 'follow', 'hr'): 1, ('follow', 'hr', '3980'): 1, ('hr', '3980', 'enact'): 1, ('3980', 'enact', 'senat'): 1, ('enact', 'senat', 'hous'): 1, ('senat', 'hous', 'repres'): 1, ('hous', 'repres', 'unit'): 1, ('repres', 'unit', 'state'): 1, ('unit', 'state', 'america'): 1, ('state', 'america', 'congress'): 1, ('america', 'congress', 'assembl'): 1, ('congress', 'assembl', 'section'): 1, ('assembl', 'section', 'short'): 1, ('section', 'short', 'titl'): 1, ('short', 'titl', 'act'): 1, ('titl', 'act', 'cite'): 1, ('act', 'cite', 'redund'): 1, ('cite', 'redund', 'elimin'): 1, ('redund', 'elimin', 'enhanc'): 5, ('elimin', 'enhanc', 'perform'): 5, ('enhanc', 'perform', 'prepared'): 5, ('perform', 'prepared', 'grant'): 5, ('prepared', 'grant', 'act'): 5, ('grant', 'act', 'sec'): 1, ('act', 'sec', 'identif'): 1, ('sec', 'identif', 'report'): 1, ('identif', 'report', 'redund'): 3, ('report', 'redund', 'develop'): 3, ('redund', 'develop', 'perform'): 3, ('develop', 'perform', 'metric'): 4, ('prepared', 'grant', 'program'): 1, ('grant', 'program', 'generaltitl'): 1, ('program', 'generaltitl', 'xx'): 1, ('generaltitl', 'xx', 'homeland'): 1, ('xx', 'homeland', 'secur'): 1, ('homeland', 'secur', 'act'): 1, ('secur', 'act', '2002'): 1, ('act', '2002', 'usc'): 1, ('2002', 'usc', '601'): 1, ('usc', '601', 'et'): 1, ('601', 'et', 'seq'): 1, ('et', 'seq', 'amend'): 1, ('seq', 'amend', 'ad'): 1, ('amend', 'ad', 'end'): 2, ('ad', 'end', 'follow'): 1, ('end', 'follow', 'new'): 1, ('follow', 'new', 'section'): 1, ('new', 'section', 'sec'): 1, ('section', 'sec', '2023'): 1, ('sec', '2023', 'identif'): 2, ('2023', 'identif', 'report'): 2, ('perform', 'metric', 'generalth'): 1, ('metric', 'generalth', 'administr'): 1, ('generalth', 'administr', 'shall'): 1, ('administr', 'shall', 'grant'): 1, ('shall', 'grant', 'section'): 1, ('grant', 'section', '2003'): 1, ('section', '2003', '2004'): 1, ('2003', '2004', 'grant'): 1, ('2004', 'grant', 'specifi'): 1, ('grant', 'specifi', 'administr'): 1, ('specifi', 'administr', 'submit'): 1, ('administr', 'submit', 'report'): 1, ('submit', 'report', 'appropri'): 1, ('report', 'appropri', 'committe'): 1, ('appropri', 'committe', 'congress'): 1, ('committe', 'congress', 'later'): 1, ('congress', 'later', '120'): 1, ('later', '120', 'day'): 2, ('120', 'day', 'date'): 1, ('day', 'date', 'enact'): 1, ('date', 'enact', 'redund'): 1, ('enact', 'redund', 'elimin'): 1, ('grant', 'act', 'octob'): 1, ('act', 'octob', '1st'): 1, ('octob', '1st', 'everi'): 1, ('1st', 'everi', 'year'): 1, ('everi', 'year', 'thereaft'): 1, ('year', 'thereaft', 'identifi'): 1, ('thereaft', 'identifi', 'redund'): 1, ('identifi', 'redund', 'rule'): 1, ('redund', 'rule', 'regul'): 1, ('rule', 'regul', 'requir'): 1, ('regul', 'requir', 'report'): 1, ('requir', 'report', 'recipi'): 1, ('report', 'recipi', 'grant'): 1, ('recipi', 'grant', 'includ'): 1, ('grant', 'includ', 'plan'): 1, ('includ', 'plan', 'elimin'): 1, ('plan', 'elimin', 'identifi'): 1, ('elimin', 'identifi', 'redund'): 1, ('identifi', 'redun ...

# %%
binary_matrix = np.zeros(shape=(len(text_trigram), len(selected_trigrmas)))

for index in range(0, len(text_trigram)):
    for token in text_trigram[index]:
        if token in selected_trigrmas:
            binary_matrix[index, selected_trigrmas.index(token)] = 1

np.savetxt("binary_matrix", binary_matrix, delimiter=",")
